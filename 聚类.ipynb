# %%
import numpy as np
import pandas as pd

# %%
# spectral聚类
data2 = pd.read_csv('./dataset/scaled_nav.csv')
data2.drop('Unnamed: 0',axis=1,inplace=True)
X = data2.drop(['fund_id','month1'],axis=1)
y_pred = SpectralClustering(n_clusters=20,affinity='sigmoid').fit_predict(X)
data2['label'] = pd.Series(y_pred)
#年化收益率
for i in range(11):
    data2[rtn_list[i]] = (data2[month_list[i+1]]-data2[month_list[i]])/data2[month_list[i]]       
tmp=1.
for rtn in rtn_list:
    tmp*=(1+data2[rtn])
data2['rtn_year'] = tmp**(12/11)-1
#最大回撤
max_drawdown_ls = []
for index in range(len(data2)):  
    tmp_series = data2.iloc[index]
    max_drawdown = 0
    for i in range(len(month_list)-1):
        for j in range(i+1,len(month_list)):
            tmp = (tmp_series[month_list[i]]-tmp_series[month_list[j]])/tmp_series[month_list[i]]
            if tmp>=max_drawdown:
                max_drawdown = tmp
                pre = i
                tail = j
    max_drawdown_ls.append(max_drawdown)
data2['max_drawdown'] = pd.Series(max_drawdown_ls)
#计算波动率
volatility_ls = []
for index in range(len(data2)):  
    tmp_series = data2.iloc[index]
    ls = []
    for rtn in rtn_list:
        ls.append(tmp_series[rtn])
    volatility_ls.append(np.std(ls)*np.sqrt(12))
data2['volatility'] = pd.Series(volatility_ls)
# 计算夏普
data2['sharpe'] = (data2['rtn_year'] - 0.4)/data2['volatility']
for i in rtn_list+month_list:
    data2.drop(i,axis=1,inplace=True)
data2.to_csv('./dataset/Spectral.csv')

# %%
#Hierarchical 层次聚类
from sklearn.cluster import AgglomerativeClustering
data2 = pd.read_csv('./dataset/scaled_nav.csv')
data2.drop('Unnamed: 0',axis=1,inplace=True)
X = data2.drop(['fund_id','month1'],axis=1)
y_pred = AgglomerativeClustering(n_clusters=20,linkage='ward').fit_predict(X)
data2['label'] = pd.Series(y_pred)
#年化收益率
for i in range(11):
    data2[rtn_list[i]] = (data2[month_list[i+1]]-data2[month_list[i]])/data2[month_list[i]]       
tmp=1.
for rtn in rtn_list:
    tmp*=(1+data2[rtn])
data2['rtn_year'] = tmp**(12/11)-1
#最大回撤
max_drawdown_ls = []
for index in range(len(data2)):  
    tmp_series = data2.iloc[index]
    max_drawdown = 0
    for i in range(len(month_list)-1):
        for j in range(i+1,len(month_list)):
            tmp = (tmp_series[month_list[i]]-tmp_series[month_list[j]])/tmp_series[month_list[i]]
            if tmp>=max_drawdown:
                max_drawdown = tmp
                pre = i
                tail = j
    max_drawdown_ls.append(max_drawdown)
data2['max_drawdown'] = pd.Series(max_drawdown_ls)
#计算波动率
volatility_ls = []
for index in range(len(data2)):  
    tmp_series = data2.iloc[index]
    ls = []
    for rtn in rtn_list:
        ls.append(tmp_series[rtn])
    volatility_ls.append(np.std(ls)*np.sqrt(12))
data2['volatility'] = pd.Series(volatility_ls)
# 计算夏普
data2['sharpe'] = (data2['rtn_year'] - 0.4)/data2['volatility']
for i in rtn_list+month_list:
    data2.drop(i,axis=1,inplace=True)
data2.to_csv('./dataset/Hierarchical.csv')

# %%
# BIRCH聚类
from sklearn.cluster import Birch
data2 = pd.read_csv('./dataset/scaled_nav.csv')
data2.drop('Unnamed: 0',axis=1,inplace=True)
X = data2.drop(['fund_id','month1'],axis=1)
y_pred = Birch(n_clusters=20).fit_predict(X)
data2['label'] = pd.Series(y_pred)
#年化收益率
for i in range(11):
    data2[rtn_list[i]] = (data2[month_list[i+1]]-data2[month_list[i]])/data2[month_list[i]]       
tmp=1.
for rtn in rtn_list:
    tmp*=(1+data2[rtn])
data2['rtn_year'] = tmp**(12/11)-1
#最大回撤
max_drawdown_ls = []
for index in range(len(data2)):  
    tmp_series = data2.iloc[index]
    max_drawdown = 0
    for i in range(len(month_list)-1):
        for j in range(i+1,len(month_list)):
            tmp = (tmp_series[month_list[i]]-tmp_series[month_list[j]])/tmp_series[month_list[i]]
            if tmp>=max_drawdown:
                max_drawdown = tmp
                pre = i
                tail = j
    max_drawdown_ls.append(max_drawdown)
data2['max_drawdown'] = pd.Series(max_drawdown_ls)
#计算波动率
volatility_ls = []
for index in range(len(data2)):  
    tmp_series = data2.iloc[index]
    ls = []
    for rtn in rtn_list:
        ls.append(tmp_series[rtn])
    volatility_ls.append(np.std(ls)*np.sqrt(12))
data2['volatility'] = pd.Series(volatility_ls)
# 计算夏普
data2['sharpe'] = (data2['rtn_year'] - 0.4)/data2['volatility']
for i in rtn_list+month_list:
    data2.drop(i,axis=1,inplace=True)
data2.to_csv('./dataset/Birch.csv')

# %%
# Mean_shift聚类
from sklearn.cluster import MeanShift
data2 = pd.read_csv('./dataset/scaled_nav.csv')
data2.drop('Unnamed: 0',axis=1,inplace=True)
X = data2.drop(['fund_id','month1'],axis=1)
y_pred = MeanShift().fit_predict(X)
data2['label'] = pd.Series(y_pred)
#年化收益率
for i in range(11):
    data2[rtn_list[i]] = (data2[month_list[i+1]]-data2[month_list[i]])/data2[month_list[i]]       
tmp=1.
for rtn in rtn_list:
    tmp*=(1+data2[rtn])
data2['rtn_year'] = tmp**(12/11)-1
#最大回撤
max_drawdown_ls = []
for index in range(len(data2)):  
    tmp_series = data2.iloc[index]
    max_drawdown = 0
    for i in range(len(month_list)-1):
        for j in range(i+1,len(month_list)):
            tmp = (tmp_series[month_list[i]]-tmp_series[month_list[j]])/tmp_series[month_list[i]]
            if tmp>=max_drawdown:
                max_drawdown = tmp
                pre = i
                tail = j
    max_drawdown_ls.append(max_drawdown)
data2['max_drawdown'] = pd.Series(max_drawdown_ls)
#计算波动率
volatility_ls = []
for index in range(len(data2)):  
    tmp_series = data2.iloc[index]
    ls = []
    for rtn in rtn_list:
        ls.append(tmp_series[rtn])
    volatility_ls.append(np.std(ls)*np.sqrt(12))
data2['volatility'] = pd.Series(volatility_ls)
# 计算夏普
data2['sharpe'] = (data2['rtn_year'] - 0.4)/data2['volatility']
for i in rtn_list+month_list:
    data2.drop(i,axis=1,inplace=True)
data2.to_csv('./dataset/Mean_shift.csv')

# %%
# OPTICS
from sklearn.cluster import OPTICS
data2 = pd.read_csv('./dataset/scaled_nav.csv')
data2.drop('Unnamed: 0',axis=1,inplace=True)
X = data2.drop(['fund_id','month1'],axis=1)
y_pred = OPTICS().fit_predict(X)
data2['label'] = pd.Series(y_pred)
dic={}
for i in list(y_pred):
    dic.setdefault(i,0)
    dic[i]+=1
print(dic)
#年化收益率
for i in range(11):
    data2[rtn_list[i]] = (data2[month_list[i+1]]-data2[month_list[i]])/data2[month_list[i]]       
tmp=1.
for rtn in rtn_list:
    tmp*=(1+data2[rtn])
data2['rtn_year'] = tmp**(12/11)-1
#最大回撤
max_drawdown_ls = []
for index in range(len(data2)):  
    tmp_series = data2.iloc[index]
    max_drawdown = 0
    for i in range(len(month_list)-1):
        for j in range(i+1,len(month_list)):
            tmp = (tmp_series[month_list[i]]-tmp_series[month_list[j]])/tmp_series[month_list[i]]
            if tmp>=max_drawdown:
                max_drawdown = tmp
                pre = i
                tail = j
    max_drawdown_ls.append(max_drawdown)
data2['max_drawdown'] = pd.Series(max_drawdown_ls)
#计算波动率
volatility_ls = []
for index in range(len(data2)):  
    tmp_series = data2.iloc[index]
    ls = []
    for rtn in rtn_list:
        ls.append(tmp_series[rtn])
    volatility_ls.append(np.std(ls)*np.sqrt(12))
data2['volatility'] = pd.Series(volatility_ls)
# 计算夏普
data2['sharpe'] = (data2['rtn_year'] - 0.4)/data2['volatility']
for i in rtn_list+month_list:
    data2.drop(i,axis=1,inplace=True)
data2.to_csv('./dataset/OPTICS.csv')
# Out:
# /Users/lanruitong/opt/anaconda3/lib/python3.8/site-packages/sklearn/cluster/_optics.py:804: RuntimeWarning: divide by zero encountered in true_divide
#   ratio = reachability_plot[:-1] / reachability_plot[1:]
# {-1: 1560, 10: 12, 5: 12, 18: 9, 17: 6, 22: 5, 14: 10, 8: 12, 12: 6, 23: 6, 3: 7, 7: 6, 2: 6, 6: 5, 19: 13, 28: 14, 27: 8, 21: 12, 4: 5, 1: 11, 24: 5, 26: 5, 0: 13, 13: 6, 16: 6, 25: 14, 15: 5, 11: 6, 9: 10, 20: 16}

# %%
# GMM
from sklearn.mixture import GaussianMixture
data2 = pd.read_csv('./dataset/scaled_nav.csv')
data2.drop('Unnamed: 0',axis=1,inplace=True)
X = data2.drop(['fund_id','month1'],axis=1)
y_pred = GaussianMixture(n_components=20).fit_predict(X)
data2['label'] = pd.Series(y_pred)
dic={}
for i in list(y_pred):
    dic.setdefault(i,0)
    dic[i]+=1
print(dic)
#年化收益率
for i in range(11):
    data2[rtn_list[i]] = (data2[month_list[i+1]]-data2[month_list[i]])/data2[month_list[i]]       
tmp=1.
for rtn in rtn_list:
    tmp*=(1+data2[rtn])
data2['rtn_year'] = tmp**(12/11)-1
#最大回撤
max_drawdown_ls = []
for index in range(len(data2)):  
    tmp_series = data2.iloc[index]
    max_drawdown = 0
    for i in range(len(month_list)-1):
        for j in range(i+1,len(month_list)):
            tmp = (tmp_series[month_list[i]]-tmp_series[month_list[j]])/tmp_series[month_list[i]]
            if tmp>=max_drawdown:
                max_drawdown = tmp
                pre = i
                tail = j
    max_drawdown_ls.append(max_drawdown)
data2['max_drawdown'] = pd.Series(max_drawdown_ls)
#计算波动率
volatility_ls = []
for index in range(len(data2)):  
    tmp_series = data2.iloc[index]
    ls = []
    for rtn in rtn_list:
        ls.append(tmp_series[rtn])
    volatility_ls.append(np.std(ls)*np.sqrt(12))
data2['volatility'] = pd.Series(volatility_ls)
# 计算夏普
data2['sharpe'] = (data2['rtn_year'] - 0.4)/data2['volatility']
for i in rtn_list+month_list:
    data2.drop(i,axis=1,inplace=True)
data2.to_csv('./dataset/GMM.csv')
# Out:
# {4: 616, 15: 131, 17: 92, 16: 171, 9: 213, 0: 84, 19: 216, 11: 128, 5: 69, 12: 30, 1: 9, 7: 1, 14: 33, 18: 1, 3: 12, 13: 1, 10: 1, 2: 1, 6: 1, 8: 1}

# %%
rtn_list
# Out:
# ['rtn2',
#  'rtn3',
#  'rtn4',
#  'rtn5',
#  'rtn6',
#  'rtn7',
#  'rtn8',
#  'rtn9',
#  'rtn10',
#  'rtn11',
#  'rtn12']

# %%
dic={}
for i in list(y_pred):
    dic.setdefault(i,0)
    dic[i]+=1
dic

# %%
from sklearn.cluster import SpectralClustering

# %%
X = data2.drop(['fund_id','month1'],axis=1)
y_pred = SpectralClustering(n_clusters=20,affinity='sigmoid').fit_predict(X)e

# %%
data2['label'] = pd.Series(y_pred)

# %%
rtn_list = ['rtn2','rtn3','rtn4','rtn5'
            ,'rtn6','rtn7','rtn8','rtn9',
           'rtn10','rtn11','rtn12']

# %%
month_list = list(data2.columns)[1:-1]
month_list
# Out:
# ['month1',
#  'month2',
#  'month3',
#  'month4',
#  'month5',
#  'month6',
#  'month7',
#  'month8',
#  'month9',
#  'month10',
#  'month11',
#  'month12']

# %%
for i in range(11):
    data2[rtn_list[i]] = (data2[month_list[i+1]]-data2[month_list[i]])/data2[month_list[i]]

# %%
data2.head()
# Out:
#       fund_id  month1    month2    month3    month4    month5    month6  \
# 0  HF0000000A     1.0  1.113330  1.201265  1.208766  1.133484  1.197108
# 1  HF0000000C     1.0  1.135147  1.263961  1.440990  1.222510  1.330167
# 2  HF0000000N     1.0  1.039040  1.123935  1.186827  1.037394  1.085068
# 3  HF00000018     1.0  1.110634  1.319022  1.583554  1.432629  1.355350
# 4  HF0000003L     1.0  1.066854  1.106736  1.152640  1.060976  1.125054
#
#      month7    month8    month9  ...      rtn3      rtn4      rtn5      rtn6  \
# 0  1.174514  1.326887  1.618527  ...  0.078984  0.006244 -0.062280  0.056131
# 1  1.301094  1.479131  1.667386  ...  0.113478  0.140059 -0.151618  0.088062
# 2  1.139326  1.228437  1.407294  ...  0.081705  0.055957 -0.125909  0.045956
# 3  1.410172  1.465984  1.636724  ...  0.187630  0.200551 -0.095308 -0.053942
# 4  1.149683  1.281877  1.459686  ...  0.037383  0.041477 -0.079524  0.060395
#
#        rtn7      rtn8      rtn9     rtn10     rtn11     rtn12
# ...

# %%
# 年化收益
tmp=1.
for rtn in rtn_list:
    tmp*=(1+data2[rtn])
data2['rtn_year'] = tmp**(12/11)-1

# %%
#最大回撤
max_drawdown_ls = []
for index in range(len(data2)):  
    tmp_series = data2.iloc[index]
    max_drawdown = 0
    for i in range(len(month_list)-1):
        for j in range(i+1,len(month_list)):
            tmp = (tmp_series[month_list[i]]-tmp_series[month_list[j]])/tmp_series[month_list[i]]
            if tmp>=max_drawdown:
                max_drawdown = tmp
                pre = i
                tail = j
    max_drawdown_ls.append(max_drawdown)
data2['max_drawdown'] = pd.Series(max_drawdown_ls)

# %%
#计算波动率
volatility_ls = []
for index in range(len(data2)):  
    tmp_series = data2.iloc[index]
    ls = []
    for rtn in rtn_list:
        ls.append(tmp_series[rtn])
    volatility_ls.append(np.std(ls)*np.sqrt(12))
data2['volatility'] = pd.Series(volatility_ls)

# %%
# 计算夏普
data2['sharpe'] = (data2['rtn_year'] - 0.4)/data2['volatility']

# %%
data2['rtn_year'].describe()
# Out:
# count    1811.000000
# mean        0.999629
# std         0.753452
# min         0.203499
# 25%         0.699740
# 50%         0.814761
# 75%         1.048220
# max        14.616490
# Name: rtn_year, dtype: float64

# %%
data2.head()
# Out:
#       fund_id  month1    month2    month3    month4    month5    month6  \
# 0  HF0000000A     1.0  1.113330  1.201265  1.208766  1.133484  1.197108
# 1  HF0000000C     1.0  1.135147  1.263961  1.440990  1.222510  1.330167
# 2  HF0000000N     1.0  1.039040  1.123935  1.186827  1.037394  1.085068
# 3  HF00000018     1.0  1.110634  1.319022  1.583554  1.432629  1.355350
# 4  HF0000003L     1.0  1.066854  1.106736  1.152640  1.060976  1.125054
#
#      month7    month8    month9  ...      rtn7      rtn8      rtn9     rtn10  \
# 0  1.174514  1.326887  1.618527  ... -0.018874  0.129732  0.219793  0.015858
# 1  1.301094  1.479131  1.667386  ... -0.021857  0.136836  0.127274 -0.045404
# 2  1.139326  1.228437  1.407294  ...  0.050004  0.078214  0.145597  0.033856
# 3  1.410172  1.465984  1.636724  ...  0.040448  0.039578  0.116468 -0.096247
# 4  1.149683  1.281877  1.459686  ...  0.021891  0.114983  0.138710  0.052767
#
#       rtn11     rtn12  rtn_year  max_drawdown  volatility    sharpe
# ...

# %%
for i in list(range(min(data2.label), max(data2.label) + 1)):
    label_data = data2[data2['label'] == i][['label', 'rtn_year', 'max_drawdown', 'volatility', 'sharpe']]
    label_data.to_csv(('/Users/lanruitong/Desktop/天府对冲基金/SpectralClustering/' + 'SpectralClustering' + str(i) + '.csv'))
