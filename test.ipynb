# %%
import numpy as np
import pandas as pd

# %%
path = '/Users/lanruitong/Desktop/天府对冲基金/交易记录/201904.csv'

# %%
data = pd.read_csv(path,error_bad_lines=False)
# Out:
# b'Skipping line 41: expected 16 fields, saw 17\n'

# %%
data
# Out:
#           日期     流水号      证券代码  证券名称      操作       发生金额       后资金额      摘要  \
# 0   20190408    8338       NaN   NaN   转存管转出       0.00       0.00   转存管转出
# 1   20190408    8339       NaN   NaN   转存管转入       0.00       0.00   转存管转入
# 2   20190409    8467       NaN   NaN    银行转存   70000.00   70000.00    银行转存
# 3   20190409   86622  123010.0  博世转债    证券买入  -10125.81   59874.19    证券买入
# 4   20190409   86624  128043.0  东音转债    证券买入  -12697.11   47177.08    证券买入
# 5   20190409   86626  128012.0  辉丰转债    证券买入  -31802.54   15374.54    证券买入
# 6   20190409   86629  128012.0  辉丰转债    证券买入  -14659.03     715.51    证券买入
# 7   20190410    7038       NaN   NaN    银行转存   90000.00   90715.51    银行转存
# 8   20190410   42213       NaN   NaN  基金资金拨出  -70778.52   19936.99  基金资金拨出
# 9   20190410   96676  123003.0  蓝思转债    证券买入  -12627.41    7309.58    证券买入
# 10  20190410   96678  128036.0  金农转债    证券买入   -7308.58       1.00    证券买入
# ...

# %%
tmp_path = './交易记录/201905.csv'

# %%
tmp = pd.read_csv(tmp_path)
tmp
# Out:
#          日期    流水号      证券代码  证券名称      操作      发生金额      后资金额      摘要   成交数量  \
# 0  20190507  39673       NaN   NaN  基金资金拨出 -19687.92 -19687.92  基金资金拨出    0.0
# 1  20190507  83575  128043.0  东音转债    证券卖出  19688.42      0.50    证券卖出 -110.0
# 2  20190508  34208       NaN   NaN  基金资金拨入  19821.59  19822.09  基金资金拨入    0.0
# 3  20190508  77617  127003.0  海印转债    证券买入 -19821.59      0.50    证券买入  200.0
# 4  20190509  33765       NaN   NaN  基金资金拨出     -0.50      0.00  基金资金拨出    0.0
#
#     成交均价  成交金额  交易市场         股东帐户 货币单位                   备注 Unnamed: 15
# 0    0.0   0.0   NaN          NaN  人民币  122扣除金额 基金代码：001621          发?
# 1  179.0   0.0  深圳Ａ股  152563184.0  人民币                 证券卖出         NaN
# 2    0.0   0.0   NaN          NaN  人民币  124增加金额 基金代码：001621          发?
# 3   99.1   0.0  深圳Ａ股  152563184.0  人民币                 证券买入         NaN
# 4    0.0   0.0   NaN          NaN  人民币  122扣除金额 基金代码：001621          发?

# %%
pd.concat([data,tmp],ignore_index=True)
# Out:
#           日期     流水号      证券代码  证券名称      操作       发生金额       后资金额      摘要  \
# 0   20190408    8338       NaN   NaN   转存管转出       0.00       0.00   转存管转出
# 1   20190408    8339       NaN   NaN   转存管转入       0.00       0.00   转存管转入
# 2   20190409    8467       NaN   NaN    银行转存   70000.00   70000.00    银行转存
# 3   20190409   86622  123010.0  博世转债    证券买入  -10125.81   59874.19    证券买入
# 4   20190409   86624  128043.0  东音转债    证券买入  -12697.11   47177.08    证券买入
# 5   20190409   86626  128012.0  辉丰转债    证券买入  -31802.54   15374.54    证券买入
# 6   20190409   86629  128012.0  辉丰转债    证券买入  -14659.03     715.51    证券买入
# 7   20190410    7038       NaN   NaN    银行转存   90000.00   90715.51    银行转存
# 8   20190410   42213       NaN   NaN  基金资金拨出  -70778.52   19936.99  基金资金拨出
# 9   20190410   96676  123003.0  蓝思转债    证券买入  -12627.41    7309.58    证券买入
# 10  20190410   96678  128036.0  金农转债    证券买入   -7308.58       1.00    证券买入
# ...

# %%
csv_name_list = ['./交易记录/201905.csv',
                './交易记录/201906.csv',
                './交易记录/201907.csv',
                './交易记录/201908.csv',
                './交易记录/201909.csv',
                './交易记录/201910.csv',
                './交易记录/201911.csv',
                './交易记录/201912.csv',
                './交易记录/202001.csv',
                './交易记录/202002.csv',
                './交易记录/202003.csv',
                './交易记录/202004.csv',
                './交易记录/202005.csv',
                './交易记录/202006.csv',]

# %%
for csv_name in csv_name_list:
    tmp_data = pd.read_csv(csv_name,error_bad_lines=False)
    data = pd.concat([data,tmp_data],ignore_index=True)
# Out:
# b'Skipping line 3: expected 16 fields, saw 17\n'
# b'Skipping line 31: expected 16 fields, saw 17\nSkipping line 56: expected 16 fields, saw 18\nSkipping line 65: expected 16 fields, saw 17\n'
# b'Skipping line 33: expected 16 fields, saw 17\nSkipping line 91: expected 16 fields, saw 18\nSkipping line 92: expected 16 fields, saw 18\nSkipping line 114: expected 16 fields, saw 18\n'
# b'Skipping line 9: expected 16 fields, saw 18\nSkipping line 19: expected 16 fields, saw 18\n'
# b'Skipping line 11: expected 16 fields, saw 17\nSkipping line 13: expected 16 fields, saw 17\nSkipping line 22: expected 16 fields, saw 18\nSkipping line 43: expected 16 fields, saw 18\nSkipping line 44: expected 16 fields, saw 18\nSkipping line 52: expected 16 fields, saw 17\n'
# ...

# %%
data['日期'] = pd.to_datetime(data['日期'])

# %%
data[:20]
# Out:
#           日期    流水号      证券代码  证券名称      操作      发生金额       后资金额      摘要  \
# 0   20190408   8338       NaN   NaN   转存管转出      0.00       0.00   转存管转出
# 1   20190408   8339       NaN   NaN   转存管转入      0.00       0.00   转存管转入
# 2   20190409   8467       NaN   NaN    银行转存  70000.00   70000.00    银行转存
# 3   20190409  86622  123010.0  博世转债    证券买入 -10125.81   59874.19    证券买入
# 4   20190409  86624  128043.0  东音转债    证券买入 -12697.11   47177.08    证券买入
# 5   20190409  86626  128012.0  辉丰转债    证券买入 -31802.54   15374.54    证券买入
# 6   20190409  86629  128012.0  辉丰转债    证券买入 -14659.03     715.51    证券买入
# 7   20190410   7038       NaN   NaN    银行转存  90000.00   90715.51    银行转存
# 8   20190410  42213       NaN   NaN  基金资金拨出 -70778.52   19936.99  基金资金拨出
# 9   20190410  96676  123003.0  蓝思转债    证券买入 -12627.41    7309.58    证券买入
# 10  20190410  96678  128036.0  金农转债    证券买入  -7308.58       1.00    证券买入
# 11  20190411   8806       NaN   NaN    银行转存  34000.00   34001.00    银行转存
# ...

# %%
data_copy = data.copy(deep=True)

# %%
data.head()
# Out:
#          日期    流水号      证券代码  证券名称     操作      发生金额      后资金额     摘要   成交数量  \
# 0  20190408   8338       NaN   NaN  转存管转出      0.00      0.00  转存管转出    0.0
# 1  20190408   8339       NaN   NaN  转存管转入      0.00      0.00  转存管转入    0.0
# 2  20190409   8467       NaN   NaN   银行转存  70000.00  70000.00   银行转存    0.0
# 3  20190409  86622  123010.0  博世转债   证券买入 -10125.81  59874.19   证券买入   90.0
# 4  20190409  86624  128043.0  东音转债   证券买入 -12697.11  47177.08   证券买入  110.0
#
#       成交均价  成交金额  交易市场        股东帐户 货币单位                   备注 Unnamed: 15
# 0    0.000   0.0   NaN         NaN  人民币       转存管转出关联流水号:617         NaN
# 1    0.000   0.0   NaN         NaN  人民币       转存管转入关联流水号:617         NaN
# 2    0.000   0.0   NaN         NaN  人民币  银行返回码[ ]返回信息[转账成功]|         NaN
# 3  112.500   0.0  深圳Ａ股  0152563184  人民币                 证券买入         NaN
# 4  115.419   0.0  深圳Ａ股  0152563184  人民币                 证券买入         NaN

# %%
date_list=[]
for i in data['日期']:
    if i not in date_list:
        date_list.append(i)

# %%
date_list[0]
# Out:
# 20190408

# %%
value = pd.DataFrame(columns=data.columns)
value
# Out:
# Empty DataFrame
# Columns: [日期, 流水号, 证券代码, 证券名称, 操作, 发生金额, 后资金额, 摘要, 成交数量, 成交均价, 成交金额, 交易市场, 股东帐户, 货币单位, 备注, Unnamed: 15]
# Index: []

# %%
value
# Out:
#           日期    流水号      证券代码  证券名称    操作      发生金额      后资金额    摘要  成交数量  \
# 13  20190411  57375  113021.0  中信转债  证券买入 -12938.46  91560.32  证券买入   0.0
#
#       成交均价  成交金额  交易市场        股东帐户 货币单位    备注  Unnamed: 15
# 13  107.82   0.0  上海Ａ股  A400231155  人民币  证券买入          NaN

# %%
#合并具体某一天内的多个对同一债券的操作
value = pd.DataFrame(columns=data.columns)
for i in range(len(tmp_data)):
    current_item = tmp_data.iloc[i]
    if pd.isnull(current_item['证券名称']):
        value = value.append(current_item)
        continue
    if current_item['证券名称'] not in list(value['证券名称']):
        value = value.append(current_item)
    else:
        value.loc[value[value['证券名称'] ==current_item['证券名称'] ].index,'成交数量']+=current_item['成交数量']
value
# Out:
#           日期    流水号      证券代码  证券名称      操作      发生金额       后资金额      摘要  \
# 11  20190411   8806       NaN   NaN    银行转存  34000.00   34001.00    银行转存
# 12  20190411  39822       NaN   NaN  基金资金拨入  70497.78  104498.78  基金资金拨入
# 13  20190411  57375  113021.0  中信转债    证券买入 -12938.46   91560.32    证券买入
# 15  20190411  75922  128012.0  辉丰转债    证券买入 -20669.65   83794.21    证券买入
# 16  20190411  75924  128036.0  金农转债    证券卖出   7619.39   91413.60    证券卖出
# 17  20190411  75926  123019.0  中来转债    证券买入 -10930.67   80482.93    证券买入
# 18  20190411  75928  127003.0  海印转债    证券买入 -22512.60   57970.33    证券买入
# 19  20190411  75931  128013.0  洪涛转债    证券买入 -20441.64   37528.69    证券买入
# 20  20190411  75934  123010.0  博世转债    证券买入 -13137.45   24391.24    证券买入
#
#      成交数量     成交均价  成交金额  交易市场        股东帐户 货币单位                   备注  \
# 11    0.0    0.000   0.0   NaN         NaN  人民币  银行返回码[ ]返回信息[转账成功]|
# 12    0.0    0.000   0.0   NaN         NaN  人民币  124增加金额 基金代码：001621
# ...

# %%
value.loc[value[value['证券名称'] == current_item['证券名称']].index,'成交数量']+=current_item['成交数量']

# %%
value
# Out:
#           日期    流水号      证券代码  证券名称    操作      发生金额      后资金额    摘要  成交数量  \
# 13  20190411  57375  113021.0  中信转债  证券买入 -12938.46  91560.32  证券买入   0.0
#
#       成交均价  成交金额  交易市场        股东帐户 货币单位    备注  Unnamed: 15
# 13  107.82   0.0  上海Ａ股  A400231155  人民币  证券买入          NaN

# %%
current_item = tmp_data.loc[14]
current_item
# Out:
# 日期               20190411
# 流水号                 57377
# 证券代码               113021
# 证券名称                 中信转债
# 操作                   证券卖出
# 发生金额              12903.5
# 后资金额               104464
# 摘要                   证券卖出
# 成交数量                 -120
# 成交均价               107.53
# 成交金额                    0
# 交易市场                 上海Ａ股
# 股东帐户           A400231155
# 货币单位                  人民币
# 备注                   证券卖出
# Unnamed: 15           NaN
# Name: 14, dtype: object

# %%
value.loc[value[value['证券名称'] == '中信转债'].index]
# Out:
#           日期    流水号      证券代码  证券名称    操作      发生金额      后资金额    摘要  成交数量  \
# 13  20190411  57375  113021.0  中信转债  证券买入 -12938.46  91560.32  证券买入   0.0
#
#       成交均价  成交金额  交易市场        股东帐户 货币单位    备注  Unnamed: 15
# 13  107.82   0.0  上海Ａ股  A400231155  人民币  证券买入          NaN

# %%
value = value.append(tmp_data.loc[13])
value
# Out:
#           日期    流水号      证券代码  证券名称    操作      发生金额      后资金额    摘要   成交数量  \
# 13  20190411  57375  113021.0  中信转债  证券买入 -12938.46  91560.32  证券买入  120.0
#
#       成交均价  成交金额  交易市场        股东帐户 货币单位    备注  Unnamed: 15
# 13  107.82   0.0  上海Ａ股  A400231155  人民币  证券买入          NaN

# %%
value.loc[13,'成交数量'] = 0
value
# Out:
#           日期    流水号      证券代码  证券名称    操作      发生金额      后资金额    摘要  成交数量  \
# 13  20190411  57375  113021.0  中信转债  证券买入 -12938.46  91560.32  证券买入   0.0
#
#       成交均价  成交金额  交易市场        股东帐户 货币单位    备注  Unnamed: 15
# 13  107.82   0.0  上海Ａ股  A400231155  人民币  证券买入          NaN

# %%
value
# Out:
#           日期    流水号      证券代码  证券名称    操作      发生金额      后资金额    摘要   成交数量  \
# 13  20190411  57375  113021.0  中信转债  证券买入 -12938.46  91560.32  证券买入  120.0
#
#       成交均价  成交金额  交易市场        股东帐户 货币单位    备注  Unnamed: 15
# 13  107.82   0.0  上海Ａ股  A400231155  人民币  证券买入          NaN

# %%
 pd.isnull(tmp_data.iloc[2]['证券名称'])
# Out:
# False

# %%
tmp_data = data[data['日期']==20190411]
tmp_data
# Out:
#           日期    流水号      证券代码  证券名称      操作      发生金额       后资金额      摘要  \
# 11  20190411   8806       NaN   NaN    银行转存  34000.00   34001.00    银行转存
# 12  20190411  39822       NaN   NaN  基金资金拨入  70497.78  104498.78  基金资金拨入
# 13  20190411  57375  113021.0  中信转债    证券买入 -12938.46   91560.32    证券买入
# 14  20190411  57377  113021.0  中信转债    证券卖出  12903.54  104463.86    证券卖出
# 15  20190411  75922  128012.0  辉丰转债    证券买入 -20669.65   83794.21    证券买入
# 16  20190411  75924  128036.0  金农转债    证券卖出   7619.39   91413.60    证券卖出
# 17  20190411  75926  123019.0  中来转债    证券买入 -10930.67   80482.93    证券买入
# 18  20190411  75928  127003.0  海印转债    证券买入 -22512.60   57970.33    证券买入
# 19  20190411  75931  128013.0  洪涛转债    证券买入 -20441.64   37528.69    证券买入
# 20  20190411  75934  123010.0  博世转债    证券买入 -13137.45   24391.24    证券买入
# 21  20190411  75937  127003.0  海印转债    证券买入 -11120.89   13270.35    证券买入
# 22  20190411  75940  128012.0  辉丰转债    证券买入 -13265.35       5.00    证券买入
#
# ...

# %% [markdown]
# # simu_index.csv

# %%
import numpy as np
import pandas as pd

# %%
path = 'simu_index.csv'
simu_data = pd.read_csv(path)

# %%
simu_data.tail()
# Out:
#         id     fund_id  profit_1y  profit_2y  profit_3y  profit_found  \
# 1498  1499  HF00005ND9     141.02        0.0        0.0        141.50
# 1499  1500  HF00005Q5I     204.35        0.0        0.0        204.35
# 1500  1501  HF00005E2U      55.87        0.0        0.0         66.00
# 1501  1502  HF00004I9V      65.60      182.1        0.0        154.73
# 1502  1503  HF00005DNX      74.58        0.0        0.0         81.74
#
#       annualized_1y  annualized_2y  annualized_3y  annualized_found  ...  \
# 1498         140.01           0.00            0.0            107.22  ...
# 1499         202.74           0.00            0.0            181.35  ...
# 1500          55.54           0.00            0.0             36.35  ...
# 1501          65.66          67.31            0.0             42.20  ...
# 1502          74.64           0.00            0.0             44.21  ...
#
#       downside_risk_3y  downside_risk_found  offensive_ability_1y  \
# ...

# %%
import quandl
quandl.ApiConfig.api_key = 'Za5wmuguhFwjM7fsbAKs'
quandl.get('CFFEX/TFH2019')
# Out:
#             Open  High  Low   Close  Pre Settle   Settle  Volume  \
# Date
# 2018-06-11   NaN   NaN  NaN  97.620      97.620   97.655     0.0
# 2018-06-12   NaN   NaN  NaN  97.620      97.655   97.505     0.0
# 2018-06-13   NaN   NaN  NaN  97.620      97.505   97.630     0.0
# 2018-06-14   NaN   NaN  NaN  97.620      97.630   97.800     0.0
# 2018-06-15   NaN   NaN  NaN  97.620      97.800   97.860     0.0
# ...          ...   ...  ...     ...         ...      ...     ...
# 2019-03-04   NaN   NaN  NaN  99.665      99.470   99.575     0.0
# 2019-03-05   NaN   NaN  NaN  99.665      99.575   99.615     0.0
# 2019-03-06   NaN   NaN  NaN  99.665      99.615   99.610     0.0
# 2019-03-07   NaN   NaN  NaN  99.665      99.610   99.840     0.0
# 2019-03-08   NaN   NaN  NaN  99.665      99.840  100.010     0.0
#
#             Open Interest  Turnover
# Date
# 2018-06-11            0.0       0.0
# 2018-06-12            0.0       0.0
# 2018-06-13            0.0       0.0
# ...

# %%
data = quandl.get_table('WIKI/PRICES', ticker = ['AAPL'], date = { 'gte': '2016-01-01', 'lte': '2019-12-31' })

# %%
data
# Out:
#      ticker       date    open     high     low    close      volume  \
# None
# 0      AAPL 2018-03-27  173.68  175.150  166.92  168.340  38962839.0
# 1      AAPL 2018-03-26  168.07  173.100  166.44  172.770  36272617.0
# 2      AAPL 2018-03-23  168.39  169.920  164.94  164.940  40248954.0
# 3      AAPL 2018-03-22  170.00  172.680  168.60  168.845  41051076.0
# 4      AAPL 2018-03-21  175.04  175.090  171.26  171.270  35247358.0
# ...     ...        ...     ...      ...     ...      ...         ...
# 555    AAPL 2016-01-08   98.55   99.110   96.76   96.960  70798016.0
# 556    AAPL 2016-01-07   98.68  100.130   96.43   96.450  81094428.0
# 557    AAPL 2016-01-06  100.56  102.370   99.87  100.700  68457388.0
# 558    AAPL 2016-01-05  105.75  105.850  102.41  102.710  55790992.0
# 559    AAPL 2016-01-04  102.61  105.368  102.00  105.350  67649387.0
#
#       ex-dividend  split_ratio    adj_open    adj_high     adj_low  \
# None
# ...

# %%
import matplotlib.pyplot as plt

# %%
x = data['date']
y = data['close']

# %%
plt.plot(x,y)
